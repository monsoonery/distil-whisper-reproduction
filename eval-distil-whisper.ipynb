# %%
# !pip install --upgrade pip
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install optimum
# !pip install deepspeed
# !pip install --upgrade datasets==2.14.7
# !pip install --upgrade transformers==4.37.0
# !pip install --upgrade accelerate
# !pip install evaluate
# !pip install jiwer

# %%
from accelerate.utils import write_basic_config
write_basic_config()

# %%
# !git config --global credential.helper store
# !huggingface-cli login --token # Fill in token huggingface

# %%
import wandb
wandb.login(key='Fill in token wandb')

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# %%
# !git lfs install
# !git clone https://huggingface.co/monsoonery/distil-whisper-nl

# %%
# !python /kaggle/input/altered/run_eval.py \
  --model_name_or_path "./distil-whisper-nl" \
  --dataset_name "facebook/voxpopuli" \
  --dataset_config_name "nl" \
  --dataset_split_name "test" \
  --text_column_name "raw_text" \
  --batch_size 16 \
  --dtype "float16" \
  --generation_max_length 128 \
  --language "nl" \
  --attn_implementation "sdpa" \
  --streaming
